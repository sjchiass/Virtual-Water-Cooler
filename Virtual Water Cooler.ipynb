# %%
# Pip Installs
#!pip install pywin32

# %%
"""Initialization"""
# Import statements
import pandas as pd
from IPython.display import display
import win32com.client as win32

# %%
"""Load the Data"""
# Read the translated, combined responses csv file skipping the column header row.
df = pd.read_csv("dataBeta.csv")

# Remove the Interest column (In Beta Mode)
df = df.iloc[:, :6]

"""
# For each row in the dataframe in the Interests column, make the list a frozenset
for i in range(len(df)):
    df.iat[i, 6] = frozenset(df.iat[i, 6].split(','))
"""

# Print df
display(df)
# Out:
#    Please enter your @canada.ca email. What is your preferred name?  \
# 0          kathryn.stevenson@canada.ca                      Kathryn
# 1                david.evans@canada.ca                         Dave
# 2         sebastien.chiasson@canada.ca                    Sebastien
# 3        kate.burnett-isaacs@canada.ca                         Kate
# 4                justfor.fun@canada.ca                       Justin
# 5           jennifer.pfitzer@canada.ca                        Jenny
# 6            chandra.boersma@canada.ca                      Chandra
# 7            kelsang.yangzom@canada.ca                      Kelsang
# 8                eric.hortop@canada.ca                  Eric Hortop
# 9                 sarah.swan@canada.ca                        Sarah
# 10             kudzayi.dondo@canada.ca                      Kudzayi
# 11           philippe.berube@canada.ca                     Philippe
# 12          maureen.campbell@canada.ca                      Maureen
# ...

# %%
"""Helper Functions"""


"""
Desc:
    Function that selects rows from a data frame based on the language preference column.
    Params: l (the language) and df (input data frame)
    Output: a data frame
"""
def langGroup(l, df):
    if (l == "English"):
        yLang = df.loc[df['What language would you like to converse in?'] == "English"]
        return yLang
    elif (l == "French"):
        yLang = df.loc[df['What language would you like to converse in?'] == "French"]
        return yLang
    else:
        return df


"""
Desc:
    Function that selects rows from a data frame based on the time preference column.
    Params: t (the time) and df (input data frame)
    Output: a data frame
"""
def tGroup(t, df):
    if (t == "Morning"):
        yT = df.loc[df['When would you like to chat?'] == "Morning"]
        return yT
    elif (l == "French"):
        yT = df.loc[df['When would you like to chat?'] == "Afternoon"]
        return yT
    else:
        return df

# %%
"""Match People Who Said Yes to Only Within Field"""

# Create a data frame of the people who said Yes
yNames = df.loc[df['Do you want to be matched ONLY WITHIN your field?'] == "Yes"]

# Group by Field
yOWF = yNames.groupby(['Which field are you in?'])

# Get the groups keys
yOWFKeys = list(yOWF.groups.keys())

# Create an empty list to store the groups
yOWFGroups = []

# Get the groups
for k in range(len(yOWFKeys)):
    yOWFGroups.append(yOWF.get_group(yOWFKeys[k]))
    display(yOWFGroups[k])

# For each group in yOWFGroups
for g in range(len(yOWFGroups)):
    
    # while the length of the group is greater than 1
    while (len(yOWFGroups[g]) > 1):
        
        # Group by language
        lang = langGroup(yOWF.iloc[0, 3], yOWFGroups[g])
        
        # Group by time
        t = tGroup(lang.iloc[0, 2], lang)
        
        # Remove the selected person
        
        
        # Shuffle the rows (Random match)
# Out:
#    Please enter your @canada.ca email. What is your preferred name?  \
# 0          kathryn.stevenson@canada.ca                      Kathryn
# 1                david.evans@canada.ca                         Dave
# 2         sebastien.chiasson@canada.ca                    Sebastien
# 3        kate.burnett-isaacs@canada.ca                         Kate
# 4                justfor.fun@canada.ca                       Justin
# 5           jennifer.pfitzer@canada.ca                        Jenny
# 6            chandra.boersma@canada.ca                      Chandra
# 7            kelsang.yangzom@canada.ca                      Kelsang
# 8                eric.hortop@canada.ca                  Eric Hortop
# 9                 sarah.swan@canada.ca                        Sarah
# 10             kudzayi.dondo@canada.ca                      Kudzayi
# 11           philippe.berube@canada.ca                     Philippe
# 12          maureen.campbell@canada.ca                      Maureen
# ...
